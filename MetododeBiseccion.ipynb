# %% [markdown]
# Tomando en cuenta lo realizado en clase, diseñar el código para el funcionamiento del método de la bisección, éste debe de estar en una función.

# %%
from math import *
import matplotlib.pyplot as plt
def biseccion(x):
    z=sqrt(x)-pi
    return z
x1=2.0
xu=4.0
tole=0.0001
n0=50
i=1
fa=f(x1)
fb=f(xu)
plt.title("Metodo Biseccion", fontsize = 20)
plt.scatter(x1,xu, n0)
plt.show()
while i<=n0:
    p=x1+(xu-x1)/2
    fp=f(p)
    if fp==0 or (xu-x1)/2<tole:
        print("")
        print("La solucion es ",p,"con ",i,"iteraciones")
        break
    i=i+1
    if fa*fp>0:
        x1=p
        fa=fp
    else:
        xu=p
        fb=fp
if i>=n0:
    print("El metodo no converge ")
# Out:
# La solucion es  3.99993896484375 con  15 iteraciones
